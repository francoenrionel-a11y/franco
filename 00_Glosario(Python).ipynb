# %% [markdown]
# <a href="https://colab.research.google.com/github/francoenrionel-a11y/franco/blob/main/00_Glosario(Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Glosario
#
# 1. division entera (`//`)
#
# >Es la division entre dos numeros en donde el resultado siempre es entero por lo tanto se redondea al menor
#
# ---
# 2. Expresiones
#
# >una coleccion de operadores y numeros
#
# ---
# 3. Valor
#
# >es el resultado de una expresion
#
# ---
# 4. Error:SyntaxError
#
# >Cuando llamo a una funcion y cometo un error en su escritura (por ejemplo: abs 42, es un erro pues no puse los paretesis en el 42)
#
# ---
# 5. La funcion (`len`)
#
# >Cuenta la cantidad de caracteres que tiene un string si no pongo los parentesis tengo un erro de sintaxis
#
# ---
# 6. Eror de tipo (TypeError)
#
# >Cuando se ejecuta una operacion que no esta asociada a un tipo (ejemplo: dividir un string pues con string solo puedo * y +)
#
# ---
# 7. Debugging
#
# >
